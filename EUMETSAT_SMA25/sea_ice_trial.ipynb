# %%
#for sea ice level 4

# %%
import matplotlib.pyplot as plt  
import matplotlib.ticker as mticker
import numpy as np

# %%
import xarray as xr

#file paths
apr = "C:/Users/Lenovo/Downloads/SEA_ICE/cmems_mod_arc_phy_anfc_nextsim_P1M-m_1741714600920.nc"
may = "C:/Users/Lenovo/Downloads/SEA_ICE/cmems_mod_arc_phy_anfc_nextsim_P1M-m_1741714612891_may.nc"

# %%
si_apr = xr.open_dataset(apr)
si_may = xr.open_dataset(may)

# %%
si_apr
# Out:
# <xarray.Dataset> Size: 46kB
# Dimensions:    (time: 1, latitude: 100, longitude: 114)
# Coordinates:
#   * time       (time) datetime64[ns] 8B 2024-04-01
#   * latitude   (latitude) float32 400B 55.75 55.78 55.8 ... 58.17 58.2 58.22
#   * longitude  (longitude) float32 456B -62.68 -62.64 -62.6 ... -58.2 -58.16
# Data variables:
#     siconc     (time, latitude, longitude) float32 46kB ...
# Attributes:
#     Conventions:       CF-1.11
#     title:             neXtSIM-F sea ice forecast, 3 km monthly averaged fiel...
#     institution:       NERSC, Jahnebakken 3, N-5007 Bergen, Norway
#     source:            neXtSIM model fields
#     history:           2023-12-02 18:58:08: cmems_postproc.py ...\n
#     subset:source:     ARCO data downloaded from the Marine Data Store using ...
#     subset:productId:  ARCTIC_ANALYSISFORECAST_PHY_ICE_002_011
#     subset:datasetId:  cmems_mod_arc_phy_anfc_nextsim_P1M-m_202311
#     subset:date:       2025-03-11T17:36:40.921Z

# %%
#common variables
common_var = set(si_apr.variables).intersection(set(si_may.variables))

# %%
common_var
# Out:
# {'latitude', 'longitude', 'siconc', 'time'}

# %%
si_may["siconc"].shape
# Out:
# (1, 100, 114)

# %%
si_apr["siconc"].shape
# Out:
# (1, 100, 114)

# %%
si_may["siconc"].dims
# Out:
# ('time', 'latitude', 'longitude')

# %%
si_apr["siconc"].dims
# Out:
# ('time', 'latitude', 'longitude')

# %%
si_may["latitude"].values == si_apr["latitude"].values
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True])

# %%
plt.imshow(si_apr['siconc'].squeeze(), cmap = 'jet')
plt.colorbar()

# %%
plt.imshow(si_may['siconc'].squeeze(), cmap = 'jet')
plt.colorbar() #[6:99, 45:91]

# %%
si_diff = si_may['siconc'].squeeze() - si_apr['siconc'].squeeze()

# %%
plt.imshow(si_diff, cmap = 'jet')
plt.colorbar()
